# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint
from datetime import date
from decimal import Decimal


# Import API key
import api_keys

# Import citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/weather_data.csv"
#output_data_file = "weather_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coordinates in lat_lngs:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
# Replace spaces with "_" to create url correctly 
    city = city.replace(" ", "_")    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Openweather map API key
api_key = api_keys.api_key

# %%
#Create a function to get json value
def get_weather_json(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/forecast"
    r = requests.get(url, params={
        "appid": api_key,
        "q": city,
        "units": "imperial"
    })
    if r.status_code ==200:
        r_json = r.json()
        return r_json
    else:
        return None

# %%
# Print the output json values
pprint.pprint(get_weather_json(city,api_key),indent =4)
# Out:
# {   'city': {   'coord': {'lat': 68.0544, 'lon': 39.5129},
#                 'country': 'RU',
#                 'id': 556268,
#                 'name': 'Ostrovnoy',
#                 'population': 4746,
#                 'sunrise': 1578215072,
#                 'sunset': 1578217747,
#                 'timezone': 10800},
#     'cnt': 40,
#     'cod': '200',
#     'list': [   {   'clouds': {'all': 68},
#                     'dt': 1578258000,
#                     'dt_txt': '2020-01-05 21:00:00',
#                     'main': {   'feels_like': -2.92,
#                                 'grnd_level': 983,
#                                 'humidity': 92,
#                                 'pressure': 1001,
#                                 'sea_level': 1001,
#                                 'temp': 14.47,
#                                 'temp_kf': 0,
#                                 'temp_max': 14.47,
#                                 'temp_min': 14.47},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 276, 'speed': 20.92}},
#                 {   'clouds': {'all': 57},
#                     'dt': 1578268800,
#                     'dt_txt': '2020-01-06 00:00:00',
#                     'main': {   'feels_like': -4.67,
#                                 'grnd_level': 985,
#                                 'humidity': 93,
#                                 'pressure': 1002,
#                                 'sea_level': 1002,
#                                 'temp': 10.02,
#                                 'temp_kf': 0,
#                                 'temp_max': 10.02,
#                                 'temp_min': 10.02},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 257, 'speed': 15.66}},
#                 {   'clouds': {'all': 62},
#                     'dt': 1578279600,
#                     'dt_txt': '2020-01-06 03:00:00',
#                     'main': {   'feels_like': -2.33,
#                                 'grnd_level': 985,
#                                 'humidity': 82,
#                                 'pressure': 1002,
#                                 'sea_level': 1002,
#                                 'temp': 12.2,
#                                 'temp_kf': 0,
#                                 'temp_max': 12.2,
#                                 'temp_min': 12.2},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 242, 'speed': 15.3}},
#                 {   'clouds': {'all': 74},
#                     'dt': 1578290400,
#                     'dt_txt': '2020-01-06 06:00:00',
#                     'main': {   'feels_like': -6.39,
#                                 'grnd_level': 984,
#                                 'humidity': 86,
#                                 'pressure': 1002,
#                                 'sea_level': 1002,
#                                 'temp': 10.99,
#                                 'temp_kf': 0,
#                                 'temp_max': 10.99,
#                                 'temp_min': 10.99},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 228, 'speed': 20.36}},
#                 {   'clouds': {'all': 99},
#                     'dt': 1578301200,
#                     'dt_txt': '2020-01-06 09:00:00',
#                     'main': {   'feels_like': -2.96,
#                                 'grnd_level': 985,
#                                 'humidity': 93,
#                                 'pressure': 1002,
#                                 'sea_level': 1002,
#                                 'temp': 13.93,
#                                 'temp_kf': 0,
#                                 'temp_max': 13.93,
#                                 'temp_min': 13.93},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 233, 'speed': 20}},
#                 {   'clouds': {'all': 99},
#                     'dt': 1578312000,
#                     'dt_txt': '2020-01-06 12:00:00',
#                     'main': {   'feels_like': 2.1,
#                                 'grnd_level': 984,
#                                 'humidity': 92,
#                                 'pressure': 1002,
#                                 'sea_level': 1002,
#                                 'temp': 16.99,
#                                 'temp_kf': 0,
#                                 'temp_max': 16.99,
#                                 'temp_min': 16.99},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 228, 'speed': 16.82}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578322800,
#                     'dt_txt': '2020-01-06 15:00:00',
#                     'main': {   'feels_like': 5.22,
#                                 'grnd_level': 985,
#                                 'humidity': 93,
#                                 'pressure': 1003,
#                                 'sea_level': 1003,
#                                 'temp': 18.16,
#                                 'temp_kf': 0,
#                                 'temp_max': 18.16,
#                                 'temp_min': 18.16},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 225, 'speed': 13.56}},
#                 {   'clouds': {'all': 99},
#                     'dt': 1578333600,
#                     'dt_txt': '2020-01-06 18:00:00',
#                     'main': {   'feels_like': 5.95,
#                                 'grnd_level': 985,
#                                 'humidity': 93,
#                                 'pressure': 1003,
#                                 'sea_level': 1003,
#                                 'temp': 17.92,
#                                 'temp_kf': 0,
#                                 'temp_max': 17.92,
#                                 'temp_min': 17.92},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 228, 'speed': 11.79}},
#                 {   'clouds': {'all': 90},
#                     'dt': 1578344400,
#                     'dt_txt': '2020-01-06 21:00:00',
#                     'main': {   'feels_like': 4.3,
#                                 'grnd_level': 986,
#                                 'humidity': 97,
#                                 'pressure': 1004,
#                                 'sea_level': 1004,
#                                 'temp': 13.84,
#                                 'temp_kf': 0,
#                                 'temp_max': 13.84,
#                                 'temp_min': 13.84},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 234, 'speed': 7.05}},
#                 {   'clouds': {'all': 88},
#                     'dt': 1578355200,
#                     'dt_txt': '2020-01-07 00:00:00',
#                     'main': {   'feels_like': 0.03,
#                                 'grnd_level': 988,
#                                 'humidity': 98,
#                                 'pressure': 1005,
#                                 'sea_level': 1005,
#                                 'temp': 9.66,
#                                 'temp_kf': 0,
#                                 'temp_max': 9.66,
#                                 'temp_min': 9.66},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 248, 'speed': 6.76}},
#                 {   'clouds': {'all': 94},
#                     'dt': 1578366000,
#                     'dt_txt': '2020-01-07 03:00:00',
#                     'main': {   'feels_like': 0.93,
#                                 'grnd_level': 989,
#                                 'humidity': 98,
#                                 'pressure': 1006,
#                                 'sea_level': 1006,
#                                 'temp': 9.36,
#                                 'temp_kf': 0,
#                                 'temp_max': 9.36,
#                                 'temp_min': 9.36},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 238, 'speed': 4.59}},
#                 {   'clouds': {'all': 79},
#                     'dt': 1578376800,
#                     'dt_txt': '2020-01-07 06:00:00',
#                     'main': {   'feels_like': 1.67,
#                                 'grnd_level': 990,
#                                 'humidity': 96,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': 10.47,
#                                 'temp_kf': 0,
#                                 'temp_max': 10.47,
#                                 'temp_min': 10.47},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 220, 'speed': 5.32}},
#                 {   'clouds': {'all': 33},
#                     'dt': 1578387600,
#                     'dt_txt': '2020-01-07 09:00:00',
#                     'main': {   'feels_like': 0.16,
#                                 'grnd_level': 989,
#                                 'humidity': 95,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': 9.95,
#                                 'temp_kf': 0,
#                                 'temp_max': 9.95,
#                                 'temp_min': 9.95},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 207, 'speed': 6.98}},
#                 {   'clouds': {'all': 56},
#                     'dt': 1578398400,
#                     'dt_txt': '2020-01-07 12:00:00',
#                     'main': {   'feels_like': 9.97,
#                                 'grnd_level': 989,
#                                 'humidity': 93,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': 23.22,
#                                 'temp_kf': 0,
#                                 'temp_max': 23.22,
#                                 'temp_min': 23.22},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 216, 'speed': 14.92}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578409200,
#                     'dt_txt': '2020-01-07 15:00:00',
#                     'main': {   'feels_like': 15.01,
#                                 'grnd_level': 987,
#                                 'humidity': 88,
#                                 'pressure': 1005,
#                                 'sea_level': 1005,
#                                 'temp': 29.53,
#                                 'temp_kf': 0,
#                                 'temp_max': 29.53,
#                                 'temp_min': 29.53},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 206, 'speed': 18.12}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578420000,
#                     'dt_txt': '2020-01-07 18:00:00',
#                     'main': {   'feels_like': 18.45,
#                                 'grnd_level': 984,
#                                 'humidity': 93,
#                                 'pressure': 1002,
#                                 'sea_level': 1002,
#                                 'temp': 32.63,
#                                 'temp_kf': 0,
#                                 'temp_max': 32.63,
#                                 'temp_min': 32.63},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 194, 'speed': 18.54}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578430800,
#                     'dt_txt': '2020-01-07 21:00:00',
#                     'main': {   'feels_like': 20.61,
#                                 'grnd_level': 982,
#                                 'humidity': 96,
#                                 'pressure': 1000,
#                                 'sea_level': 1000,
#                                 'temp': 34.23,
#                                 'temp_kf': 0,
#                                 'temp_max': 34.23,
#                                 'temp_min': 34.23},
#                     'snow': {'3h': 0.44},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 199, 'speed': 18.16}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578441600,
#                     'dt_txt': '2020-01-08 00:00:00',
#                     'main': {   'feels_like': 22.62,
#                                 'grnd_level': 980,
#                                 'humidity': 96,
#                                 'pressure': 998,
#                                 'sea_level': 998,
#                                 'temp': 33.66,
#                                 'temp_kf': 0,
#                                 'temp_max': 33.66,
#                                 'temp_min': 33.66},
#                     'snow': {'3h': 1.12},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 217, 'speed': 13.42}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578452400,
#                     'dt_txt': '2020-01-08 03:00:00',
#                     'main': {   'feels_like': 21.24,
#                                 'grnd_level': 979,
#                                 'humidity': 96,
#                                 'pressure': 997,
#                                 'sea_level': 997,
#                                 'temp': 33.64,
#                                 'temp_kf': 0,
#                                 'temp_max': 33.64,
#                                 'temp_min': 33.64},
#                     'snow': {'3h': 0.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 235, 'speed': 15.84}},
#                 {   'clouds': {'all': 96},
#                     'dt': 1578463200,
#                     'dt_txt': '2020-01-08 06:00:00',
#                     'main': {   'feels_like': 19.78,
#                                 'grnd_level': 978,
#                                 'humidity': 90,
#                                 'pressure': 995,
#                                 'sea_level': 995,
#                                 'temp': 32.88,
#                                 'temp_kf': 0,
#                                 'temp_max': 32.88,
#                                 'temp_min': 32.88},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 228, 'speed': 16.49}},
#                 {   'clouds': {'all': 89},
#                     'dt': 1578474000,
#                     'dt_txt': '2020-01-08 09:00:00',
#                     'main': {   'feels_like': 11.75,
#                                 'grnd_level': 976,
#                                 'humidity': 88,
#                                 'pressure': 994,
#                                 'sea_level': 994,
#                                 'temp': 28.63,
#                                 'temp_kf': 0,
#                                 'temp_max': 28.63,
#                                 'temp_min': 28.63},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 218, 'speed': 22.15}},
#                 {   'clouds': {'all': 95},
#                     'dt': 1578484800,
#                     'dt_txt': '2020-01-08 12:00:00',
#                     'main': {   'feels_like': 12.31,
#                                 'grnd_level': 973,
#                                 'humidity': 87,
#                                 'pressure': 991,
#                                 'sea_level': 991,
#                                 'temp': 31.05,
#                                 'temp_kf': 0,
#                                 'temp_max': 31.05,
#                                 'temp_min': 31.05},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 215, 'speed': 25.86}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578495600,
#                     'dt_txt': '2020-01-08 15:00:00',
#                     'main': {   'feels_like': 14.25,
#                                 'grnd_level': 968,
#                                 'humidity': 95,
#                                 'pressure': 985,
#                                 'sea_level': 985,
#                                 'temp': 33.1,
#                                 'temp_kf': 0,
#                                 'temp_max': 33.1,
#                                 'temp_min': 33.1},
#                     'snow': {'3h': 1.25},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 204, 'speed': 27.07}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578506400,
#                     'dt_txt': '2020-01-08 18:00:00',
#                     'main': {   'feels_like': 19,
#                                 'grnd_level': 963,
#                                 'humidity': 98,
#                                 'pressure': 981,
#                                 'sea_level': 981,
#                                 'temp': 35.08,
#                                 'temp_kf': 0,
#                                 'temp_max': 35.08,
#                                 'temp_min': 35.08},
#                     'rain': {'3h': 1.56},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 225, 'speed': 22.88}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578517200,
#                     'dt_txt': '2020-01-08 21:00:00',
#                     'main': {   'feels_like': 19.94,
#                                 'grnd_level': 963,
#                                 'humidity': 94,
#                                 'pressure': 980,
#                                 'sea_level': 980,
#                                 'temp': 35.92,
#                                 'temp_kf': 0,
#                                 'temp_max': 35.92,
#                                 'temp_min': 35.92},
#                     'rain': {'3h': 0.63},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 240, 'speed': 22.66}},
#                 {   'clouds': {'all': 86},
#                     'dt': 1578528000,
#                     'dt_txt': '2020-01-09 00:00:00',
#                     'main': {   'feels_like': 17.76,
#                                 'grnd_level': 964,
#                                 'humidity': 86,
#                                 'pressure': 981,
#                                 'sea_level': 981,
#                                 'temp': 33.94,
#                                 'temp_kf': 0,
#                                 'temp_max': 33.94,
#                                 'temp_min': 33.94},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 264, 'speed': 21.92}},
#                 {   'clouds': {'all': 30},
#                     'dt': 1578538800,
#                     'dt_txt': '2020-01-09 03:00:00',
#                     'main': {   'feels_like': 11.66,
#                                 'grnd_level': 965,
#                                 'humidity': 81,
#                                 'pressure': 983,
#                                 'sea_level': 983,
#                                 'temp': 27.34,
#                                 'temp_kf': 0,
#                                 'temp_max': 27.34,
#                                 'temp_min': 27.34},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03n',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 254, 'speed': 19.37}},
#                 {   'clouds': {'all': 15},
#                     'dt': 1578549600,
#                     'dt_txt': '2020-01-09 06:00:00',
#                     'main': {   'feels_like': 6.01,
#                                 'grnd_level': 966,
#                                 'humidity': 84,
#                                 'pressure': 984,
#                                 'sea_level': 984,
#                                 'temp': 23.22,
#                                 'temp_kf': 0,
#                                 'temp_max': 23.22,
#                                 'temp_min': 23.22},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'few clouds',
#                                        'icon': '02n',
#                                        'id': 801,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 230, 'speed': 21.54}},
#                 {   'clouds': {'all': 1},
#                     'dt': 1578560400,
#                     'dt_txt': '2020-01-09 09:00:00',
#                     'main': {   'feels_like': 3.58,
#                                 'grnd_level': 965,
#                                 'humidity': 89,
#                                 'pressure': 983,
#                                 'sea_level': 983,
#                                 'temp': 22.64,
#                                 'temp_kf': 0,
#                                 'temp_max': 22.64,
#                                 'temp_min': 22.64},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 234, 'speed': 24.96}},
#                 {   'clouds': {'all': 5},
#                     'dt': 1578571200,
#                     'dt_txt': '2020-01-09 12:00:00',
#                     'main': {   'feels_like': 8.06,
#                                 'grnd_level': 965,
#                                 'humidity': 87,
#                                 'pressure': 983,
#                                 'sea_level': 983,
#                                 'temp': 25.9,
#                                 'temp_kf': 0,
#                                 'temp_max': 25.9,
#                                 'temp_min': 25.9},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01n',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 237, 'speed': 23.24}},
#                 {   'clouds': {'all': 56},
#                     'dt': 1578582000,
#                     'dt_txt': '2020-01-09 15:00:00',
#                     'main': {   'feels_like': 9.86,
#                                 'grnd_level': 965,
#                                 'humidity': 88,
#                                 'pressure': 982,
#                                 'sea_level': 982,
#                                 'temp': 24.82,
#                                 'temp_kf': 0,
#                                 'temp_max': 24.82,
#                                 'temp_min': 24.82},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 245, 'speed': 18.01}},
#                 {   'clouds': {'all': 78},
#                     'dt': 1578592800,
#                     'dt_txt': '2020-01-09 18:00:00',
#                     'main': {   'feels_like': 9.64,
#                                 'grnd_level': 965,
#                                 'humidity': 89,
#                                 'pressure': 983,
#                                 'sea_level': 983,
#                                 'temp': 24.33,
#                                 'temp_kf': 0,
#                                 'temp_max': 24.33,
#                                 'temp_min': 24.33},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 243, 'speed': 17.47}},
#                 {   'clouds': {'all': 77},
#                     'dt': 1578603600,
#                     'dt_txt': '2020-01-09 21:00:00',
#                     'main': {   'feels_like': 10.27,
#                                 'grnd_level': 966,
#                                 'humidity': 91,
#                                 'pressure': 983,
#                                 'sea_level': 983,
#                                 'temp': 24.6,
#                                 'temp_kf': 0,
#                                 'temp_max': 24.6,
#                                 'temp_min': 24.6},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 241, 'speed': 16.98}},
#                 {   'clouds': {'all': 88},
#                     'dt': 1578614400,
#                     'dt_txt': '2020-01-10 00:00:00',
#                     'main': {   'feels_like': 10.76,
#                                 'grnd_level': 967,
#                                 'humidity': 94,
#                                 'pressure': 984,
#                                 'sea_level': 984,
#                                 'temp': 28.17,
#                                 'temp_kf': 0,
#                                 'temp_max': 28.17,
#                                 'temp_min': 28.17},
#                     'snow': {'3h': 0.31},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 288, 'speed': 23.29}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578625200,
#                     'dt_txt': '2020-01-10 03:00:00',
#                     'main': {   'feels_like': 6.31,
#                                 'grnd_level': 969,
#                                 'humidity': 80,
#                                 'pressure': 986,
#                                 'sea_level': 986,
#                                 'temp': 24.1,
#                                 'temp_kf': 0,
#                                 'temp_max': 24.1,
#                                 'temp_min': 24.1},
#                     'snow': {'3h': 0.38},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 284, 'speed': 22.5}},
#                 {   'clouds': {'all': 82},
#                     'dt': 1578636000,
#                     'dt_txt': '2020-01-10 06:00:00',
#                     'main': {   'feels_like': 5,
#                                 'grnd_level': 971,
#                                 'humidity': 85,
#                                 'pressure': 988,
#                                 'sea_level': 988,
#                                 'temp': 19.44,
#                                 'temp_kf': 0,
#                                 'temp_max': 19.44,
#                                 'temp_min': 19.44},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 267, 'speed': 16.08}},
#                 {   'clouds': {'all': 0},
#                     'dt': 1578646800,
#                     'dt_txt': '2020-01-10 09:00:00',
#                     'main': {   'feels_like': 5.92,
#                                 'grnd_level': 972,
#                                 'humidity': 81,
#                                 'pressure': 989,
#                                 'sea_level': 989,
#                                 'temp': 21.65,
#                                 'temp_kf': 0,
#                                 'temp_max': 21.65,
#                                 'temp_min': 21.65},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 277, 'speed': 18.54}},
#                 {   'clouds': {'all': 0},
#                     'dt': 1578657600,
#                     'dt_txt': '2020-01-10 12:00:00',
#                     'main': {   'feels_like': 5.88,
#                                 'grnd_level': 972,
#                                 'humidity': 81,
#                                 'pressure': 990,
#                                 'sea_level': 990,
#                                 'temp': 19.71,
#                                 'temp_kf': 0,
#                                 'temp_max': 19.71,
#                                 'temp_min': 19.71},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01n',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 245, 'speed': 14.9}},
#                 {   'clouds': {'all': 46},
#                     'dt': 1578668400,
#                     'dt_txt': '2020-01-10 15:00:00',
#                     'main': {   'feels_like': 2.71,
#                                 'grnd_level': 971,
#                                 'humidity': 87,
#                                 'pressure': 989,
#                                 'sea_level': 989,
#                                 'temp': 22.06,
#                                 'temp_kf': 0,
#                                 'temp_max': 22.06,
#                                 'temp_min': 22.06},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03n',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 232, 'speed': 25.28}},
#                 {   'clouds': {'all': 73},
#                     'dt': 1578679200,
#                     'dt_txt': '2020-01-10 18:00:00',
#                     'main': {   'feels_like': 9.46,
#                                 'grnd_level': 970,
#                                 'humidity': 88,
#                                 'pressure': 987,
#                                 'sea_level': 987,
#                                 'temp': 26.06,
#                                 'temp_kf': 0,
#                                 'temp_max': 26.06,
#                                 'temp_min': 26.06},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 241, 'speed': 21.12}}],
#     'message': 0}

# %%
# Declare the list of elements for data frame
out_cities = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# %%
# Set the initial values for set and record variables
record = 0
set = 1

# Print the output as per the required output
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for in_city in cities:
    response = get_weather_json(in_city.replace(" ", "_"), api_key)
    
    if response:
        # Append the values for all DataFrame variables 
        cloudiness.append(response['list'][0]['clouds']['all'])
        city_data = response['city']
        country.append(city_data['country'])
        date.append(response['list'][0]['dt'])
        humidity.append(response['list'][0]['main']['humidity'])
        latitude.append(Decimal(city_data['coord']['lat']).quantize(Decimal(10) ** -2  ))
        longitude.append(Decimal(city_data['coord']['lon']).quantize(Decimal(10) ** -2  ))
        max_temp.append(Decimal(response['list'][0]['main']['temp_max']).quantize(Decimal(10) ** -2  ))
        wind_speed.append(response['list'][0]['wind']['speed'])
        # Check to increment the value of set as per the required output and append the cities for DataFrame
        if record > 49:
            record = 1
            set += 1
            out_cities.append(in_city)
        else:
            record += 1
            out_cities.append(in_city)
        print(f"Processing Record {record} of Set {set} | {in_city}")
        #time.sleep(0.001)
    # Check if the city is not in the list
    else:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | dzhebariki-khaya
# City not found. Skipping...
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | ambon
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | albany
# City not found. Skipping...
# Processing Record 6 of Set 1 | klaksvik
# City not found. Skipping...
# Processing Record 7 of Set 1 | mata
# City not found. Skipping...
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | yaan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | usinsk
# City not found. Skipping...
# Processing Record 12 of Set 1 | namie
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 16 of Set 1 | bonthe
# City not found. Skipping...
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | huilong
# Processing Record 23 of Set 1 | harnai
# Processing Record 24 of Set 1 | hobart
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 1 | grindavik
# Processing Record 26 of Set 1 | marienburg
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 30 of Set 1 | sept-iles
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | upata
# City not found. Skipping...
# Processing Record 33 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 34 of Set 1 | kabalo
# Processing Record 35 of Set 1 | pundaguitan
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | yulara
# City not found. Skipping...
# Processing Record 39 of Set 1 | leshukonskoye
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | pochutla
# Processing Record 43 of Set 1 | caxito
# Processing Record 44 of Set 1 | luderitz
# City not found. Skipping...
# Processing Record 45 of Set 1 | manaure
# Processing Record 46 of Set 1 | sheridan
# Processing Record 47 of Set 1 | sinnamary
# Processing Record 48 of Set 1 | chhatak
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | tasiilaq
# City not found. Skipping...
# Processing Record 2 of Set 2 | havelock
# Processing Record 3 of Set 2 | nurobod
# Processing Record 4 of Set 2 | ulaangom
# Processing Record 5 of Set 2 | muchkapskiy
# Processing Record 6 of Set 2 | naze
# Processing Record 7 of Set 2 | biak
# Processing Record 8 of Set 2 | bluefields
# Processing Record 9 of Set 2 | zheleznodorozhnyy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | qasigiannguit
# Processing Record 13 of Set 2 | amsterdam
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 2 | batie
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | lhokseumawe
# Processing Record 18 of Set 2 | ancud
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | roma
# Processing Record 22 of Set 2 | zlitan
# Processing Record 23 of Set 2 | tautira
# Processing Record 24 of Set 2 | vao
# Processing Record 25 of Set 2 | bilma
# City not found. Skipping...
# Processing Record 26 of Set 2 | padang
# Processing Record 27 of Set 2 | ihosy
# Processing Record 28 of Set 2 | mehamn
# Processing Record 29 of Set 2 | ansfelden
# Processing Record 30 of Set 2 | sitka
# Processing Record 31 of Set 2 | isangel
# City not found. Skipping...
# Processing Record 32 of Set 2 | bima
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 2 | khorramshahr
# Processing Record 34 of Set 2 | male
# Processing Record 35 of Set 2 | kieta
# Processing Record 36 of Set 2 | sungairaya
# City not found. Skipping...
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | marystown
# Processing Record 39 of Set 2 | sharhorod
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 42 of Set 2 | kuopio
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 2 | parabel
# City not found. Skipping...
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | bubaque
# City not found. Skipping...
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | olden
# Processing Record 50 of Set 2 | tuktoyaktuk
# Processing Record 1 of Set 3 | vardo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 3 | biggar
# Processing Record 3 of Set 3 | camacha
# City not found. Skipping...
# Processing Record 4 of Set 3 | kamenka
# Processing Record 5 of Set 3 | komsomolskiy
# City not found. Skipping...
# Processing Record 6 of Set 3 | ouadda
# Processing Record 7 of Set 3 | fortuna
# City not found. Skipping...
# Processing Record 8 of Set 3 | homer
# Processing Record 9 of Set 3 | nalut
# City not found. Skipping...
# Processing Record 10 of Set 3 | mwingi
# City not found. Skipping...
# Processing Record 11 of Set 3 | wanaka
# City not found. Skipping...
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | hualmay
# Processing Record 15 of Set 3 | darnah
# Processing Record 16 of Set 3 | kutum
# City not found. Skipping...
# Processing Record 17 of Set 3 | remanso
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | zhigansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | gat
# Processing Record 21 of Set 3 | bonfim
# Processing Record 22 of Set 3 | tual
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | buraydah
# City not found. Skipping...
# Processing Record 25 of Set 3 | mbuji-mayi
# Processing Record 26 of Set 3 | tongzi
# City not found. Skipping...
# Processing Record 27 of Set 3 | mariental
# Processing Record 28 of Set 3 | gaoua
# Processing Record 29 of Set 3 | airai
# City not found. Skipping...
# Processing Record 30 of Set 3 | sobolevo
# City not found. Skipping...
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | beloha
# City not found. Skipping...
# Processing Record 35 of Set 3 | fukue
# Processing Record 36 of Set 3 | chegdomyn
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | vanavara
# Processing Record 39 of Set 3 | ambilobe
# Processing Record 40 of Set 3 | qarqin
# Processing Record 41 of Set 3 | goundam
# Processing Record 42 of Set 3 | gigmoto
# City not found. Skipping...
# Processing Record 43 of Set 3 | yerbogachen
# Processing Record 44 of Set 3 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 3 | nikolskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 3 | sabha
# Processing Record 47 of Set 3 | baykit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 3 | baherden
# Processing Record 49 of Set 3 | jennings
# Processing Record 50 of Set 3 | kibala
# Processing Record 1 of Set 4 | sussex
# Processing Record 2 of Set 4 | lavrentiya
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | birjand
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 4 | nazarovo
# Processing Record 7 of Set 4 | sydney
# Processing Record 8 of Set 4 | dzhubga
# Processing Record 9 of Set 4 | ayan
# City not found. Skipping...
# Processing Record 10 of Set 4 | tommot
# Processing Record 11 of Set 4 | warrnambool
# City not found. Skipping...
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | harer
# Processing Record 14 of Set 4 | hambantota
# Processing Record 15 of Set 4 | tongren
# City not found. Skipping...
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | loiza
# Processing Record 18 of Set 4 | pitimbu
# Processing Record 19 of Set 4 | aykhal
# Processing Record 20 of Set 4 | namatanai
# City not found. Skipping...
# Processing Record 21 of Set 4 | lorengau
# Processing Record 22 of Set 4 | ondarroa
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | sorland
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | hirado
# Processing Record 27 of Set 4 | chor
# Processing Record 28 of Set 4 | buala
# Processing Record 29 of Set 4 | okha
# Processing Record 30 of Set 4 | kayerkan
# Processing Record 31 of Set 4 | chicama
# Processing Record 32 of Set 4 | paamiut
# Processing Record 33 of Set 4 | faya
# City not found. Skipping...
# Processing Record 34 of Set 4 | lompoc
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | mandalgovi
# Processing Record 37 of Set 4 | livingston
# Processing Record 38 of Set 4 | celestun
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 4 | parnamirim
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | fairview
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 4 | hovd
# City not found. Skipping...
# Processing Record 43 of Set 4 | olinda
# Processing Record 44 of Set 4 | manbij
# City not found. Skipping...
# Processing Record 45 of Set 4 | moussoro
# Processing Record 46 of Set 4 | kupang
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | chalmette
# City not found. Skipping...
# Processing Record 49 of Set 4 | odlabari
# City not found. Skipping...
# Processing Record 50 of Set 4 | sarny
# Processing Record 1 of Set 5 | aklavik
# City not found. Skipping...
# Processing Record 2 of Set 5 | tuatapere
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 5 | mahebourg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 5 | mecca
# Processing Record 5 of Set 5 | yellowknife
# Processing Record 6 of Set 5 | tessalit
# City not found. Skipping...
# Processing Record 7 of Set 5 | nichinan
# Processing Record 8 of Set 5 | warburg
# Processing Record 9 of Set 5 | chokurdakh
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | chapais
# Processing Record 12 of Set 5 | vostok
# Processing Record 13 of Set 5 | kaitangata
# Processing Record 14 of Set 5 | bandarbeyla
# Processing Record 15 of Set 5 | bereda
# Processing Record 16 of Set 5 | trapani
# City not found. Skipping...
# Processing Record 17 of Set 5 | northam
# Processing Record 18 of Set 5 | andijon
# Processing Record 19 of Set 5 | hobyo
# Processing Record 20 of Set 5 | coihaique
# Processing Record 21 of Set 5 | katsuura
# City not found. Skipping...
# Processing Record 22 of Set 5 | constitucion
# City not found. Skipping...
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | esna
# Processing Record 25 of Set 5 | lindas
# Processing Record 26 of Set 5 | bulgan
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | galle
# Processing Record 29 of Set 5 | riyadh
# Processing Record 30 of Set 5 | brookhaven
# Processing Record 31 of Set 5 | ellensburg
# City not found. Skipping...
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | xuzhou
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 5 | acuitzio
# City not found. Skipping...
# Processing Record 35 of Set 5 | talara
# Processing Record 36 of Set 5 | sistranda
# Processing Record 37 of Set 5 | taperoa
# Processing Record 38 of Set 5 | winnemucca
# Processing Record 39 of Set 5 | iquique
# Processing Record 40 of Set 5 | smidovich
# Processing Record 41 of Set 5 | ceres
# Processing Record 42 of Set 5 | dudinka
# City not found. Skipping...
# Processing Record 43 of Set 5 | requena
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 5 | necochea
# Processing Record 45 of Set 5 | zhuanghe
# Processing Record 46 of Set 5 | tigre
# Processing Record 47 of Set 5 | mazsalaca
# Processing Record 48 of Set 5 | kafanchan
# Processing Record 49 of Set 5 | saint-augustin
# Processing Record 50 of Set 5 | esil
# City not found. Skipping...
# Processing Record 1 of Set 6 | marrakesh
# Processing Record 2 of Set 6 | pangody
# Processing Record 3 of Set 6 | ust-maya
# City not found. Skipping...
# Processing Record 4 of Set 6 | amahai
# City not found. Skipping...
# Processing Record 5 of Set 6 | asasa
# Processing Record 6 of Set 6 | neftcala
# Processing Record 7 of Set 6 | nagato
# Processing Record 8 of Set 6 | petrivka
# Processing Record 9 of Set 6 | jumla
# Processing Record 10 of Set 6 | vavoua
# Processing Record 11 of Set 6 | boli
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 6 | college
# Processing Record 13 of Set 6 | fatezh
# Processing Record 14 of Set 6 | moree
# Processing Record 15 of Set 6 | palana
# Processing Record 16 of Set 6 | tura
# Processing Record 17 of Set 6 | keskin
# City not found. Skipping...
# Processing Record 18 of Set 6 | yar-sale
# Processing Record 19 of Set 6 | salalah
# Processing Record 20 of Set 6 | vetlanda
# City not found. Skipping...
# Processing Record 21 of Set 6 | rossano
# City not found. Skipping...
# Processing Record 22 of Set 6 | scottsboro
# Processing Record 23 of Set 6 | sechura
# City not found. Skipping...
# Processing Record 24 of Set 6 | avigliana
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 6 | juneau
# Processing Record 26 of Set 6 | gao
# Processing Record 27 of Set 6 | adrar
# Processing Record 28 of Set 6 | tulum
# Processing Record 29 of Set 6 | scottsbluff
# Processing Record 30 of Set 6 | uravakonda
# Processing Record 31 of Set 6 | lata
# City not found. Skipping...
# Processing Record 32 of Set 6 | sinnar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 6 | batagay
# Processing Record 34 of Set 6 | cottonwood
# City not found. Skipping...
# Processing Record 35 of Set 6 | nicoya
# Processing Record 36 of Set 6 | kollegal
# Processing Record 37 of Set 6 | tiznit
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | kirkwood
# Processing Record 40 of Set 6 | tomatlan
# Processing Record 41 of Set 6 | george
# City not found. Skipping...
# Processing Record 42 of Set 6 | cherskiy
# Processing Record 43 of Set 6 | vila
# City not found. Skipping...
# Processing Record 44 of Set 6 | taltal
# Processing Record 45 of Set 6 | kuusamo
# Processing Record 46 of Set 6 | canton
# Processing Record 47 of Set 6 | havoysund
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 6 | klishkivtsi
# Processing Record 49 of Set 6 | leningradskiy
# Processing Record 50 of Set 6 | mont-dore
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 7 | douentza
# City not found. Skipping...
# Processing Record 2 of Set 7 | veraval
# Processing Record 3 of Set 7 | callaway
# Processing Record 4 of Set 7 | zaysan
# Processing Record 5 of Set 7 | beringovskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | golden
# City not found. Skipping...
# Processing Record 7 of Set 7 | ust-uda
# Processing Record 8 of Set 7 | zhicheng
# Processing Record 9 of Set 7 | deputatskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | poykovskiy
# City not found. Skipping...
# Processing Record 11 of Set 7 | aleksandrovka
# Processing Record 12 of Set 7 | miri
# Processing Record 13 of Set 7 | soyo
# Processing Record 14 of Set 7 | severo-yeniseyskiy
# Processing Record 15 of Set 7 | trincomalee
# Processing Record 16 of Set 7 | vilhena
# Processing Record 17 of Set 7 | avera
# Processing Record 18 of Set 7 | longyan
# Processing Record 19 of Set 7 | pottsville
# Processing Record 20 of Set 7 | corrente
# Processing Record 21 of Set 7 | yertarskiy
# Processing Record 22 of Set 7 | sambava
# City not found. Skipping...
# Processing Record 23 of Set 7 | phuket
# Processing Record 24 of Set 7 | dicabisagan
# Processing Record 25 of Set 7 | tazmalt
# Processing Record 26 of Set 7 | pentecoste
# City not found. Skipping...
# Processing Record 27 of Set 7 | maningrida
# City not found. Skipping...
# Processing Record 28 of Set 7 | bayan
# Processing Record 29 of Set 7 | birao
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 7 | mabaruma
# City not found. Skipping...
# Processing Record 31 of Set 7 | urdoma
# Processing Record 32 of Set 7 | berlevag
# Processing Record 33 of Set 7 | whitehorse
# Processing Record 34 of Set 7 | carutapera
# Processing Record 35 of Set 7 | nipawin
# Processing Record 36 of Set 7 | nishihara
# Processing Record 37 of Set 7 | fairbanks
# Processing Record 38 of Set 7 | espanola
# Processing Record 39 of Set 7 | tulsipur
# Processing Record 40 of Set 7 | yashkul
# Processing Record 41 of Set 7 | bambanglipuro
# City not found. Skipping...
# Processing Record 42 of Set 7 | zhezkazgan
# City not found. Skipping...
# Processing Record 43 of Set 7 | kisesa
# City not found. Skipping...
# Processing Record 44 of Set 7 | dongsheng
# Processing Record 45 of Set 7 | nizwa
# City not found. Skipping...
# Processing Record 46 of Set 7 | morondava
# Processing Record 47 of Set 7 | coahuayana
# Processing Record 48 of Set 7 | jacareacanga
# City not found. Skipping...
# Processing Record 49 of Set 7 | limuru
# Processing Record 50 of Set 7 | sarlat-la-caneda
# Processing Record 1 of Set 8 | ordzhonikidze
# Processing Record 2 of Set 8 | cadiz
# Processing Record 3 of Set 8 | caldwell
# Processing Record 4 of Set 8 | altay
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | sandwick
# Processing Record 7 of Set 8 | vanimo
# Processing Record 8 of Set 8 | jinchang
# Processing Record 9 of Set 8 | oussouye
# City not found. Skipping...
# Processing Record 10 of Set 8 | balkanabat
# Processing Record 11 of Set 8 | pedregulho
# Processing Record 12 of Set 8 | menongue
# Processing Record 13 of Set 8 | erenhot
# Processing Record 14 of Set 8 | hohhot
# Processing Record 15 of Set 8 | luquillo
# Processing Record 16 of Set 8 | kamaishi
# City not found. Skipping...
# Processing Record 17 of Set 8 | mishelevka
# Processing Record 18 of Set 8 | inhambane
# Processing Record 19 of Set 8 | bogashevo
# Processing Record 20 of Set 8 | broome
# Processing Record 21 of Set 8 | messina
# Processing Record 22 of Set 8 | bezlyudivka
# Processing Record 23 of Set 8 | uvinza
# Processing Record 24 of Set 8 | marawi
# Processing Record 25 of Set 8 | smyrna
# City not found. Skipping...
# Processing Record 26 of Set 8 | kholm
# Processing Record 27 of Set 8 | klyuchi
# Processing Record 28 of Set 8 | zonguldak
# City not found. Skipping...
# Processing Record 29 of Set 8 | oktyabrskoye
# City not found. Skipping...
# Processing Record 30 of Set 8 | kruisfontein
# Processing Record 31 of Set 8 | hirara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 8 | yatou
# Processing Record 33 of Set 8 | severo-kurilsk
# Processing Record 34 of Set 8 | yarim
# Processing Record 35 of Set 8 | kahului
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | margate
# Processing Record 38 of Set 8 | sabang
# Processing Record 39 of Set 8 | weligama
# Processing Record 40 of Set 8 | mehkar
# Processing Record 41 of Set 8 | dawlatabad
# Processing Record 42 of Set 8 | augustow
# Processing Record 43 of Set 8 | jaisalmer
# Processing Record 44 of Set 8 | koumac
# Processing Record 45 of Set 8 | malindi
# Processing Record 46 of Set 8 | arlit
# City not found. Skipping...
# Processing Record 47 of Set 8 | port-gentil
# City not found. Skipping...
# Processing Record 48 of Set 8 | aksu
# Processing Record 49 of Set 8 | waipawa
# Processing Record 50 of Set 8 | wanning
# City not found. Skipping...
# Processing Record 1 of Set 9 | lethem
# City not found. Skipping...
# Processing Record 2 of Set 9 | solnechnyy
# Processing Record 3 of Set 9 | sarangani
# Processing Record 4 of Set 9 | tokmak
# Processing Record 5 of Set 9 | moron
# Processing Record 6 of Set 9 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 7 of Set 9 | ierapetra
# Processing Record 8 of Set 9 | suez
# Processing Record 9 of Set 9 | ludvika
# Processing Record 10 of Set 9 | muros
# City not found. Skipping...
# Processing Record 11 of Set 9 | noumea
# Processing Record 12 of Set 9 | lieksa
# Processing Record 13 of Set 9 | lasa
# Processing Record 14 of Set 9 | opuwo
# Processing Record 15 of Set 9 | eureka
# Processing Record 16 of Set 9 | zasheyek
# Processing Record 17 of Set 9 | hanzhong
# Processing Record 18 of Set 9 | biskamzha
# Processing Record 19 of Set 9 | pangoa
# City not found. Skipping...
# Processing Record 20 of Set 9 | sapulpa
# Processing Record 21 of Set 9 | bulawayo
# Processing Record 22 of Set 9 | atar
# Processing Record 23 of Set 9 | ahipara
# City not found. Skipping...
# Processing Record 24 of Set 9 | ilulissat
# City not found. Skipping...
# Processing Record 25 of Set 9 | manturovo
# Processing Record 26 of Set 9 | wamba
# Processing Record 27 of Set 9 | moissala
# Processing Record 28 of Set 9 | figeac
# Processing Record 29 of Set 9 | lohja
# Processing Record 30 of Set 9 | saint-georges
# Processing Record 31 of Set 9 | vershino-darasunskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | guthrie
# Processing Record 33 of Set 9 | ketchikan
# Processing Record 34 of Set 9 | durusu
# Processing Record 35 of Set 9 | mildura
# Processing Record 36 of Set 9 | kisangani
# Processing Record 37 of Set 9 | dingle
# City not found. Skipping...
# Processing Record 38 of Set 9 | magistralnyy
# Processing Record 39 of Set 9 | pangnirtung
# Processing Record 40 of Set 9 | alyangula
# Processing Record 41 of Set 9 | elat
# Processing Record 42 of Set 9 | sibolga
# Processing Record 43 of Set 9 | mazagao
# Processing Record 44 of Set 9 | verkhoyansk
# City not found. Skipping...
# Processing Record 45 of Set 9 | ushtobe
# City not found. Skipping...
# Processing Record 46 of Set 9 | karasjok
# Processing Record 47 of Set 9 | thibodaux
# City not found. Skipping...
# Processing Record 48 of Set 9 | hokitika
# City not found. Skipping...
# Processing Record 49 of Set 9 | matara
# Processing Record 50 of Set 9 | baie-comeau
# Processing Record 1 of Set 10 | takoradi
# Processing Record 2 of Set 10 | kedgwick
# Processing Record 3 of Set 10 | rognan
# City not found. Skipping...
# Processing Record 4 of Set 10 | ocos
# Processing Record 5 of Set 10 | kloulklubed
# Processing Record 6 of Set 10 | kachiry
# Processing Record 7 of Set 10 | antalaha
# Processing Record 8 of Set 10 | lichinga
# Processing Record 9 of Set 10 | trelew
# Processing Record 10 of Set 10 | lagoa
# Processing Record 11 of Set 10 | barsovo
# City not found. Skipping...
# Processing Record 12 of Set 10 | aksarka
# City not found. Skipping...
# Processing Record 13 of Set 10 | lukovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 10 | katangli
# Processing Record 15 of Set 10 | boysun
# Processing Record 16 of Set 10 | zyryanka
# Processing Record 17 of Set 10 | manggar
# City not found. Skipping...
# Processing Record 18 of Set 10 | kozmodemyansk
# Processing Record 19 of Set 10 | zigong
# City not found. Skipping...
# Processing Record 20 of Set 10 | tankhoy
# Processing Record 21 of Set 10 | portland
# Processing Record 22 of Set 10 | shingu
# Processing Record 23 of Set 10 | baruun-urt
# Processing Record 24 of Set 10 | ostrovnoy
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Set the dictionary for the DataFrame

raw_data = {
            "City": out_cities,
            "Cloudiness": cloudiness,
            "Country": country,
            "Date": date,
            "Humidity": humidity ,
            "Lat": latitude ,
            "Lng": longitude ,
            "Max Temp": max_temp ,
            "Wind Speed": wind_speed  
            
            }

# %%
# Convert to DataFrame and display the DataFrame
df_weather = pd.DataFrame(raw_data)
df_weather.head()
# Out:
#                City  Cloudiness Country        Date  Humidity     Lat  \
# 0  dzhebariki-khaya         100      RU  1578258000        99   62.22
# 1              hilo          56      US  1578258000        80   19.71
# 2             ambon           0      FR  1578258000        84   47.55
# 3          cidreira           0      BR  1578258000        82  -30.17
# 4            albany          95      US  1578258000        68   42.65
#
#        Lng Max Temp  Wind Speed
# 0   135.80    -5.58        1.10
# 1  -155.08    75.85       11.63
# 2    -2.56    42.15        8.08
# 3   -50.22    74.61       19.30
# 4   -73.75    28.27       12.66

# %%
# Save the output to a csv file "weather_data.csv"
df_weather.to_csv('Output_CSV/weather_data.csv')
#df_weather.to_csv("weather_data.csv")

# %%
# Display the count of all the variables
df_weather.count()
# Out:
# City          474
# Cloudiness    474
# Country       474
# Date          474
# Humidity      474
# Lat           474
# Lng           474
# Max Temp      474
# Wind Speed    474
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date
today_date = date.today().strftime('%m/%d/%Y') 
today_date
# Out:
# '01/05/2020'

# %%
plt.scatter(df_weather["Lat"], df_weather["Max Temp"], edgecolors = "black", facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature ("+ today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max temp (F)")
#plt.xlim(-80,100)
#plt.ylim(min(df_weather["Max Temp"])-20 ,max(df_weather["Max Temp"])+20)
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

#plt.savefig("LatitudeVsTemperaturePlot.png")
plt.savefig("Output_Plots/LatitudeVsTemperaturePlot.pnge.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Humidity"], edgecolors = "black", facecolors="skyblue", s=20)
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title(" City Latitude vs. Humidity (" + today_date + ")" ) 
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsHumidityPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Cloudiness"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsCloudinessPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Wind Speed"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsWindSpeedPlot.png")
plt.show()
