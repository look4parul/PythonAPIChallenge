# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint
from datetime import date
from decimal import Decimal


# Import API key
import api_keys

# Import citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/weather_data.csv"
#output_data_file = "weather_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coordinates in lat_lngs:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
# Replace spaces with "_" to create url correctly 
    city = city.replace(" ", "_")    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Openweather map API key
api_key = api_keys.api_key

# %%
#Create a function to get json value
def get_weather_json(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/forecast"
    r = requests.get(url, params={
        "appid": api_key,
        "q": city,
        "units": "imperial"
    })
    if r.status_code ==200:
        r_json = r.json()
        return r_json
    else:
        return None

# %%
# Print the output json values
#pprint.pprint(get_weather_json(city,api_key),indent =4)
# Out:
# {   'city': {   'coord': {'lat': 55.7433, 'lon': -97.8635},
#                 'country': 'CA',
#                 'id': 6165406,
#                 'name': 'Thompson',
#                 'population': 12467,
#                 'sunrise': 1578236375,
#                 'sunset': 1578262405,
#                 'timezone': -21600},
#     'cnt': 40,
#     'cod': '200',
#     'list': [   {   'clouds': {'all': 100},
#                     'dt': 1578258000,
#                     'dt_txt': '2020-01-05 21:00:00',
#                     'main': {   'feels_like': -4.02,
#                                 'grnd_level': 981,
#                                 'humidity': 87,
#                                 'pressure': 1008,
#                                 'sea_level': 1008,
#                                 'temp': 7.57,
#                                 'temp_kf': 1.18,
#                                 'temp_max': 7.57,
#                                 'temp_min': 5.45},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 303, 'speed': 9.75}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578268800,
#                     'dt_txt': '2020-01-06 00:00:00',
#                     'main': {   'feels_like': -10.26,
#                                 'grnd_level': 982,
#                                 'humidity': 89,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 2.64,
#                                 'temp_kf': 0.88,
#                                 'temp_max': 2.64,
#                                 'temp_min': 1.06},
#                     'snow': {'3h': 0.06},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 286, 'speed': 11.74}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578279600,
#                     'dt_txt': '2020-01-06 03:00:00',
#                     'main': {   'feels_like': -16.91,
#                                 'grnd_level': 983,
#                                 'humidity': 92,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': -5.46,
#                                 'temp_kf': 0.59,
#                                 'temp_max': -5.46,
#                                 'temp_min': -6.52},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 286, 'speed': 8.68}},
#                 {   'clouds': {'all': 53},
#                     'dt': 1578290400,
#                     'dt_txt': '2020-01-06 06:00:00',
#                     'main': {   'feels_like': -23.1,
#                                 'grnd_level': 983,
#                                 'humidity': 95,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': -13.14,
#                                 'temp_kf': 0.29,
#                                 'temp_max': -13.14,
#                                 'temp_min': -13.67},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 274, 'speed': 5.68}},
#                 {   'clouds': {'all': 70},
#                     'dt': 1578301200,
#                     'dt_txt': '2020-01-06 09:00:00',
#                     'main': {   'feels_like': -24.84,
#                                 'grnd_level': 983,
#                                 'humidity': 95,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': -15.3,
#                                 'temp_kf': 0,
#                                 'temp_max': -15.3,
#                                 'temp_min': -15.3},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 275, 'speed': 4.85}},
#                 {   'clouds': {'all': 85},
#                     'dt': 1578312000,
#                     'dt_txt': '2020-01-06 12:00:00',
#                     'main': {   'feels_like': -19.46,
#                                 'grnd_level': 980,
#                                 'humidity': 94,
#                                 'pressure': 1008,
#                                 'sea_level': 1008,
#                                 'temp': -11.4,
#                                 'temp_kf': 0,
#                                 'temp_max': -11.4,
#                                 'temp_min': -11.4},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 228, 'speed': 2.39}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578322800,
#                     'dt_txt': '2020-01-06 15:00:00',
#                     'main': {   'feels_like': -17.39,
#                                 'grnd_level': 980,
#                                 'humidity': 98,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': -9.47,
#                                 'temp_kf': 0,
#                                 'temp_max': -9.47,
#                                 'temp_min': -9.47},
#                     'snow': {'3h': 0.25},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13d',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 280, 'speed': 2.28}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578333600,
#                     'dt_txt': '2020-01-06 18:00:00',
#                     'main': {   'feels_like': -12.26,
#                                 'grnd_level': 979,
#                                 'humidity': 94,
#                                 'pressure': 1006,
#                                 'sea_level': 1006,
#                                 'temp': -4.34,
#                                 'temp_kf': 0,
#                                 'temp_max': -4.34,
#                                 'temp_min': -4.34},
#                     'snow': {'3h': 0.31},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13d',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 345, 'speed': 2.48}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578344400,
#                     'dt_txt': '2020-01-06 21:00:00',
#                     'main': {   'feels_like': -12.71,
#                                 'grnd_level': 979,
#                                 'humidity': 95,
#                                 'pressure': 1006,
#                                 'sea_level': 1006,
#                                 'temp': -3.21,
#                                 'temp_kf': 0,
#                                 'temp_max': -3.21,
#                                 'temp_min': -3.21},
#                     'snow': {'3h': 0.06},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13d',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 316, 'speed': 5.39}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578355200,
#                     'dt_txt': '2020-01-07 00:00:00',
#                     'main': {   'feels_like': -18.42,
#                                 'grnd_level': 981,
#                                 'humidity': 95,
#                                 'pressure': 1008,
#                                 'sea_level': 1008,
#                                 'temp': -7.1,
#                                 'temp_kf': 0,
#                                 'temp_max': -7.1,
#                                 'temp_min': -7.1},
#                     'snow': {'3h': 0.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 320, 'speed': 8.39}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578366000,
#                     'dt_txt': '2020-01-07 03:00:00',
#                     'main': {   'feels_like': -21.51,
#                                 'grnd_level': 983,
#                                 'humidity': 92,
#                                 'pressure': 1011,
#                                 'sea_level': 1011,
#                                 'temp': -9.22,
#                                 'temp_kf': 0,
#                                 'temp_max': -9.22,
#                                 'temp_min': -9.22},
#                     'snow': {'3h': 0.13},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 319, 'speed': 10}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578376800,
#                     'dt_txt': '2020-01-07 06:00:00',
#                     'main': {   'feels_like': -23.8,
#                                 'grnd_level': 985,
#                                 'humidity': 91,
#                                 'pressure': 1013,
#                                 'sea_level': 1013,
#                                 'temp': -11.83,
#                                 'temp_kf': 0,
#                                 'temp_max': -11.83,
#                                 'temp_min': -11.83},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 312, 'speed': 9.28}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578387600,
#                     'dt_txt': '2020-01-07 09:00:00',
#                     'main': {   'feels_like': -23.21,
#                                 'grnd_level': 988,
#                                 'humidity': 91,
#                                 'pressure': 1016,
#                                 'sea_level': 1016,
#                                 'temp': -10.88,
#                                 'temp_kf': 0,
#                                 'temp_max': -10.88,
#                                 'temp_min': -10.88},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 319, 'speed': 9.98}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578398400,
#                     'dt_txt': '2020-01-07 12:00:00',
#                     'main': {   'feels_like': -26.95,
#                                 'grnd_level': 990,
#                                 'humidity': 92,
#                                 'pressure': 1018,
#                                 'sea_level': 1018,
#                                 'temp': -15.38,
#                                 'temp_kf': 0,
#                                 'temp_max': -15.38,
#                                 'temp_min': -15.38},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 309, 'speed': 8.46}},
#                 {   'clouds': {'all': 69},
#                     'dt': 1578409200,
#                     'dt_txt': '2020-01-07 15:00:00',
#                     'main': {   'feels_like': -29.78,
#                                 'grnd_level': 992,
#                                 'humidity': 93,
#                                 'pressure': 1020,
#                                 'sea_level': 1020,
#                                 'temp': -18.83,
#                                 'temp_kf': 0,
#                                 'temp_max': -18.83,
#                                 'temp_min': -18.83},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 309, 'speed': 7.23}},
#                 {   'clouds': {'all': 52},
#                     'dt': 1578420000,
#                     'dt_txt': '2020-01-07 18:00:00',
#                     'main': {   'feels_like': -25.46,
#                                 'grnd_level': 994,
#                                 'humidity': 90,
#                                 'pressure': 1023,
#                                 'sea_level': 1023,
#                                 'temp': -14.08,
#                                 'temp_kf': 0,
#                                 'temp_max': -14.08,
#                                 'temp_min': -14.08},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 307, 'speed': 8.12}},
#                 {   'clouds': {'all': 74},
#                     'dt': 1578430800,
#                     'dt_txt': '2020-01-07 21:00:00',
#                     'main': {   'feels_like': -24.05,
#                                 'grnd_level': 996,
#                                 'humidity': 90,
#                                 'pressure': 1024,
#                                 'sea_level': 1024,
#                                 'temp': -12.93,
#                                 'temp_kf': 0,
#                                 'temp_max': -12.93,
#                                 'temp_min': -12.93},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 304, 'speed': 7.72}},
#                 {   'clouds': {'all': 52},
#                     'dt': 1578441600,
#                     'dt_txt': '2020-01-08 00:00:00',
#                     'main': {   'feels_like': -29.42,
#                                 'grnd_level': 997,
#                                 'humidity': 94,
#                                 'pressure': 1026,
#                                 'sea_level': 1026,
#                                 'temp': -19.25,
#                                 'temp_kf': 0,
#                                 'temp_max': -19.25,
#                                 'temp_min': -19.25},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 295, 'speed': 5.86}},
#                 {   'clouds': {'all': 0},
#                     'dt': 1578452400,
#                     'dt_txt': '2020-01-08 03:00:00',
#                     'main': {   'feels_like': -31.74,
#                                 'grnd_level': 998,
#                                 'humidity': 95,
#                                 'pressure': 1027,
#                                 'sea_level': 1027,
#                                 'temp': -22.02,
#                                 'temp_kf': 0,
#                                 'temp_max': -22.02,
#                                 'temp_min': -22.02},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01n',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 301, 'speed': 4.99}},
#                 {   'clouds': {'all': 3},
#                     'dt': 1578463200,
#                     'dt_txt': '2020-01-08 06:00:00',
#                     'main': {   'feels_like': -33.99,
#                                 'grnd_level': 999,
#                                 'humidity': 95,
#                                 'pressure': 1028,
#                                 'sea_level': 1028,
#                                 'temp': -24.05,
#                                 'temp_kf': 0,
#                                 'temp_max': -24.05,
#                                 'temp_min': -24.05},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01n',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 277, 'speed': 5.32}},
#                 {   'clouds': {'all': 3},
#                     'dt': 1578474000,
#                     'dt_txt': '2020-01-08 09:00:00',
#                     'main': {   'feels_like': -35.07,
#                                 'grnd_level': 999,
#                                 'humidity': 96,
#                                 'pressure': 1028,
#                                 'sea_level': 1028,
#                                 'temp': -25.46,
#                                 'temp_kf': 0,
#                                 'temp_max': -25.46,
#                                 'temp_min': -25.46},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01n',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 279, 'speed': 4.72}},
#                 {   'clouds': {'all': 1},
#                     'dt': 1578484800,
#                     'dt_txt': '2020-01-08 12:00:00',
#                     'main': {   'feels_like': -35.75,
#                                 'grnd_level': 1000,
#                                 'humidity': 95,
#                                 'pressure': 1029,
#                                 'sea_level': 1029,
#                                 'temp': -26.19,
#                                 'temp_kf': 0,
#                                 'temp_max': -26.19,
#                                 'temp_min': -26.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01n',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 266, 'speed': 4.59}},
#                 {   'clouds': {'all': 5},
#                     'dt': 1578495600,
#                     'dt_txt': '2020-01-08 15:00:00',
#                     'main': {   'feels_like': -36.22,
#                                 'grnd_level': 999,
#                                 'humidity': 96,
#                                 'pressure': 1029,
#                                 'sea_level': 1029,
#                                 'temp': -27.4,
#                                 'temp_kf': 0,
#                                 'temp_max': -27.4,
#                                 'temp_min': -27.4},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 278, 'speed': 3.24}},
#                 {   'clouds': {'all': 7},
#                     'dt': 1578506400,
#                     'dt_txt': '2020-01-08 18:00:00',
#                     'main': {   'feels_like': -25.11,
#                                 'grnd_level': 1000,
#                                 'humidity': 91,
#                                 'pressure': 1029,
#                                 'sea_level': 1029,
#                                 'temp': -16.98,
#                                 'temp_kf': 0,
#                                 'temp_max': -16.98,
#                                 'temp_min': -16.98},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 247, 'speed': 2.28}},
#                 {   'clouds': {'all': 73},
#                     'dt': 1578517200,
#                     'dt_txt': '2020-01-08 21:00:00',
#                     'main': {   'feels_like': -21.98,
#                                 'grnd_level': 999,
#                                 'humidity': 94,
#                                 'pressure': 1028,
#                                 'sea_level': 1028,
#                                 'temp': -14.6,
#                                 'temp_kf': 0,
#                                 'temp_max': -14.6,
#                                 'temp_min': -14.6},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 118, 'speed': 1.05}},
#                 {   'clouds': {'all': 87},
#                     'dt': 1578528000,
#                     'dt_txt': '2020-01-09 00:00:00',
#                     'main': {   'feels_like': -29,
#                                 'grnd_level': 999,
#                                 'humidity': 95,
#                                 'pressure': 1028,
#                                 'sea_level': 1028,
#                                 'temp': -20.43,
#                                 'temp_kf': 0,
#                                 'temp_max': -20.43,
#                                 'temp_min': -20.43},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 112, 'speed': 2.98}},
#                 {   'clouds': {'all': 97},
#                     'dt': 1578538800,
#                     'dt_txt': '2020-01-09 03:00:00',
#                     'main': {   'feels_like': -30.51,
#                                 'grnd_level': 999,
#                                 'humidity': 96,
#                                 'pressure': 1027,
#                                 'sea_level': 1027,
#                                 'temp': -21.05,
#                                 'temp_kf': 0,
#                                 'temp_max': -21.05,
#                                 'temp_min': -21.05},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 69, 'speed': 4.56}},
#                 {   'clouds': {'all': 98},
#                     'dt': 1578549600,
#                     'dt_txt': '2020-01-09 06:00:00',
#                     'main': {   'feels_like': -30.1,
#                                 'grnd_level': 998,
#                                 'humidity': 95,
#                                 'pressure': 1027,
#                                 'sea_level': 1027,
#                                 'temp': -19.91,
#                                 'temp_kf': 0,
#                                 'temp_max': -19.91,
#                                 'temp_min': -19.91},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 62, 'speed': 5.88}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578560400,
#                     'dt_txt': '2020-01-09 09:00:00',
#                     'main': {   'feels_like': -28.77,
#                                 'grnd_level': 997,
#                                 'humidity': 94,
#                                 'pressure': 1025,
#                                 'sea_level': 1025,
#                                 'temp': -17.73,
#                                 'temp_kf': 0,
#                                 'temp_max': -17.73,
#                                 'temp_min': -17.73},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 58, 'speed': 7.43}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578571200,
#                     'dt_txt': '2020-01-09 12:00:00',
#                     'main': {   'feels_like': -28.62,
#                                 'grnd_level': 996,
#                                 'humidity': 94,
#                                 'pressure': 1024,
#                                 'sea_level': 1024,
#                                 'temp': -17.09,
#                                 'temp_kf': 0,
#                                 'temp_max': -17.09,
#                                 'temp_min': -17.09},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 55, 'speed': 8.34}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578582000,
#                     'dt_txt': '2020-01-09 15:00:00',
#                     'main': {   'feels_like': -28.19,
#                                 'grnd_level': 995,
#                                 'humidity': 94,
#                                 'pressure': 1024,
#                                 'sea_level': 1024,
#                                 'temp': -16.29,
#                                 'temp_kf': 0,
#                                 'temp_max': -16.29,
#                                 'temp_min': -16.29},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 50, 'speed': 9.01}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578592800,
#                     'dt_txt': '2020-01-09 18:00:00',
#                     'main': {   'feels_like': -26.27,
#                                 'grnd_level': 994,
#                                 'humidity': 94,
#                                 'pressure': 1022,
#                                 'sea_level': 1022,
#                                 'temp': -14.12,
#                                 'temp_kf': 0,
#                                 'temp_max': -14.12,
#                                 'temp_min': -14.12},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 46, 'speed': 9.55}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578603600,
#                     'dt_txt': '2020-01-09 21:00:00',
#                     'main': {   'feels_like': -24.97,
#                                 'grnd_level': 993,
#                                 'humidity': 96,
#                                 'pressure': 1021,
#                                 'sea_level': 1021,
#                                 'temp': -12.51,
#                                 'temp_kf': 0,
#                                 'temp_max': -12.51,
#                                 'temp_min': -12.51},
#                     'snow': {'3h': 0.19},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13d',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 41, 'speed': 10.16}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578614400,
#                     'dt_txt': '2020-01-10 00:00:00',
#                     'main': {   'feels_like': -25.1,
#                                 'grnd_level': 993,
#                                 'humidity': 96,
#                                 'pressure': 1022,
#                                 'sea_level': 1022,
#                                 'temp': -12.71,
#                                 'temp_kf': 0,
#                                 'temp_max': -12.71,
#                                 'temp_min': -12.71},
#                     'snow': {'3h': 0.37},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 41, 'speed': 10.02}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578625200,
#                     'dt_txt': '2020-01-10 03:00:00',
#                     'main': {   'feels_like': -25.8,
#                                 'grnd_level': 993,
#                                 'humidity': 96,
#                                 'pressure': 1022,
#                                 'sea_level': 1022,
#                                 'temp': -13.43,
#                                 'temp_kf': 0,
#                                 'temp_max': -13.43,
#                                 'temp_min': -13.43},
#                     'snow': {'3h': 0.5},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 42, 'speed': 9.98}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578636000,
#                     'dt_txt': '2020-01-10 06:00:00',
#                     'main': {   'feels_like': -25.65,
#                                 'grnd_level': 994,
#                                 'humidity': 96,
#                                 'pressure': 1022,
#                                 'sea_level': 1022,
#                                 'temp': -14.12,
#                                 'temp_kf': 0,
#                                 'temp_max': -14.12,
#                                 'temp_min': -14.12},
#                     'snow': {'3h': 0.38},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 37, 'speed': 8.46}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578646800,
#                     'dt_txt': '2020-01-10 09:00:00',
#                     'main': {   'feels_like': -26.77,
#                                 'grnd_level': 993,
#                                 'humidity': 96,
#                                 'pressure': 1022,
#                                 'sea_level': 1022,
#                                 'temp': -15.23,
#                                 'temp_kf': 0,
#                                 'temp_max': -15.23,
#                                 'temp_min': -15.23},
#                     'snow': {'3h': 0.38},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 33, 'speed': 8.43}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578657600,
#                     'dt_txt': '2020-01-10 12:00:00',
#                     'main': {   'feels_like': -26.39,
#                                 'grnd_level': 994,
#                                 'humidity': 96,
#                                 'pressure': 1023,
#                                 'sea_level': 1023,
#                                 'temp': -15.34,
#                                 'temp_kf': 0,
#                                 'temp_max': -15.34,
#                                 'temp_min': -15.34},
#                     'snow': {'3h': 0.31},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13n',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 24, 'speed': 7.56}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578668400,
#                     'dt_txt': '2020-01-10 15:00:00',
#                     'main': {   'feels_like': -26.19,
#                                 'grnd_level': 995,
#                                 'humidity': 96,
#                                 'pressure': 1023,
#                                 'sea_level': 1023,
#                                 'temp': -15.16,
#                                 'temp_kf': 0,
#                                 'temp_max': -15.16,
#                                 'temp_min': -15.16},
#                     'snow': {'3h': 0.44},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13d',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 23, 'speed': 7.54}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578679200,
#                     'dt_txt': '2020-01-10 18:00:00',
#                     'main': {   'feels_like': -23.69,
#                                 'grnd_level': 995,
#                                 'humidity': 96,
#                                 'pressure': 1023,
#                                 'sea_level': 1023,
#                                 'temp': -13.09,
#                                 'temp_kf': 0,
#                                 'temp_max': -13.09,
#                                 'temp_min': -13.09},
#                     'snow': {'3h': 0.37},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light snow',
#                                        'icon': '13d',
#                                        'id': 600,
#                                        'main': 'Snow'}],
#                     'wind': {'deg': 15, 'speed': 6.85}}],
#     'message': 0}

# %%
# Declare the list of elements for data frame
out_cities = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# %%
# Set the initial values for set and record variables
record = 0
set = 1

# Print the output as per the required output
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for in_city in cities:
    response = get_weather_json(in_city.replace(" ", "_"), api_key)
    
    if response:
        # Append the values for all DataFrame variables 
        cloudiness.append(response['list'][0]['clouds']['all'])
        city_data = response['city']
        country.append(city_data['country'])
        date.append(response['list'][0]['dt'])
        humidity.append(response['list'][0]['main']['humidity'])
        latitude.append(Decimal(city_data['coord']['lat']).quantize(Decimal(10) ** -2  ))
        longitude.append(Decimal(city_data['coord']['lon']).quantize(Decimal(10) ** -2  ))
        max_temp.append(Decimal(response['list'][0]['main']['temp_max']).quantize(Decimal(10) ** -2  ))
        wind_speed.append(response['list'][0]['wind']['speed'])
        # Check to increment the value of set as per the required output and append the cities for DataFrame
        if record > 49:
            record = 1
            set += 1
            out_cities.append(in_city)
        else:
            record += 1
            out_cities.append(in_city)
        print(f"Processing Record {record} of Set {set} | {in_city}")
        #time.sleep(0.001)
    # Check if the city is not in the list
    else:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | arman
# Processing Record 6 of Set 1 | yulara
# Processing Record 7 of Set 1 | ulkan
# Processing Record 8 of Set 1 | roma
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | gilbues
# Processing Record 13 of Set 1 | luga
# Processing Record 14 of Set 1 | bethel
# City not found. Skipping...
# Processing Record 15 of Set 1 | zaterechnyy
# City not found. Skipping...
# Processing Record 16 of Set 1 | korsakovo
# Processing Record 17 of Set 1 | lakatoro
# City not found. Skipping...
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | popondetta
# Processing Record 21 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 22 of Set 1 | beloha
# Processing Record 23 of Set 1 | acari
# City not found. Skipping...
# Processing Record 24 of Set 1 | namibe
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 27 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 28 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 29 of Set 1 | grants
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | praia
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | jalu
# City not found. Skipping...
# Processing Record 35 of Set 1 | tezu
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | husavik
# City not found. Skipping...
# Processing Record 39 of Set 1 | geraldton
# Processing Record 40 of Set 1 | okhotsk
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | harper
# Processing Record 43 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 44 of Set 1 | honiara
# Processing Record 45 of Set 1 | muswellbrook
# City not found. Skipping...
# Processing Record 46 of Set 1 | vanavara
# Processing Record 47 of Set 1 | matara
# City not found. Skipping...
# Processing Record 48 of Set 1 | maryborough
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 50 of Set 1 | bilma
# Processing Record 1 of Set 2 | serra
# Processing Record 2 of Set 2 | billings
# Processing Record 3 of Set 2 | yar-sale
# Processing Record 4 of Set 2 | baykit
# Processing Record 5 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | adrar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 2 | avarua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 2 | tiksi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 2 | tuban
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | salalah
# Processing Record 13 of Set 2 | jurm
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | kingman
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 2 | kaseda
# City not found. Skipping...
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | sertaozinho
# Processing Record 19 of Set 2 | omboue
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | guerande
# City not found. Skipping...
# Processing Record 26 of Set 2 | kondinskoye
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | nacala
# City not found. Skipping...
# Processing Record 30 of Set 2 | portland
# Processing Record 31 of Set 2 | mujiayingzi
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 2 | shalakusha
# Processing Record 33 of Set 2 | chuy
# City not found. Skipping...
# Processing Record 34 of Set 2 | labuhan
# Processing Record 35 of Set 2 | salym
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | rudnyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | torbay
# City not found. Skipping...
# Processing Record 43 of Set 2 | ulaangom
# Processing Record 44 of Set 2 | hamilton
# Processing Record 45 of Set 2 | labytnangi
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 2 | udachnyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | chokurdakh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 2 | vynohradivka
# City not found. Skipping...
# Processing Record 1 of Set 3 | muros
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | kibaya
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | bushehr
# City not found. Skipping...
# Processing Record 7 of Set 3 | altay
# Processing Record 8 of Set 3 | guaymas
# Processing Record 9 of Set 3 | niquero
# Processing Record 10 of Set 3 | fukue
# Processing Record 11 of Set 3 | saskylakh
# City not found. Skipping...
# Processing Record 12 of Set 3 | longyearbyen
# Processing Record 13 of Set 3 | ketchikan
# City not found. Skipping...
# Processing Record 14 of Set 3 | doka
# Processing Record 15 of Set 3 | zyryanskoye
# City not found. Skipping...
# Processing Record 16 of Set 3 | sayyan
# City not found. Skipping...
# Processing Record 17 of Set 3 | havelock
# Processing Record 18 of Set 3 | thompson
# City not found. Skipping...
# Processing Record 19 of Set 3 | wasilla
# Processing Record 20 of Set 3 | nantucket
# Processing Record 21 of Set 3 | karratha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 3 | acurenam
# City not found. Skipping...
# Processing Record 23 of Set 3 | mitsamiouli
# Processing Record 24 of Set 3 | fortuna
# Processing Record 25 of Set 3 | shingu
# Processing Record 26 of Set 3 | bundaberg
# Processing Record 27 of Set 3 | sorong
# Processing Record 28 of Set 3 | boyolangu
# Processing Record 29 of Set 3 | pangody
# Processing Record 30 of Set 3 | oriximina
# Processing Record 31 of Set 3 | camalu
# Processing Record 32 of Set 3 | tarko-sale
# Processing Record 33 of Set 3 | paternion
# City not found. Skipping...
# Processing Record 34 of Set 3 | gunjur
# Processing Record 35 of Set 3 | tombouctou
# Processing Record 36 of Set 3 | iqaluit
# City not found. Skipping...
# Processing Record 37 of Set 3 | klaksvik
# City not found. Skipping...
# Processing Record 38 of Set 3 | lyubim
# Processing Record 39 of Set 3 | atar
# City not found. Skipping...
# Processing Record 40 of Set 3 | renqiu
# Processing Record 41 of Set 3 | laguna
# City not found. Skipping...
# Processing Record 42 of Set 3 | chara
# Processing Record 43 of Set 3 | buritizeiro
# City not found. Skipping...
# Processing Record 44 of Set 3 | mandalgovi
# City not found. Skipping...
# Processing Record 45 of Set 3 | olden
# Processing Record 46 of Set 3 | phalodi
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | negotino
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 3 | buique
# Processing Record 50 of Set 3 | pyaozerskiy
# Processing Record 1 of Set 4 | kathu
# Processing Record 2 of Set 4 | dabakala
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | luderitz
# Processing Record 5 of Set 4 | fairbanks
# Processing Record 6 of Set 4 | pangnirtung
# Processing Record 7 of Set 4 | hovd
# Processing Record 8 of Set 4 | burnie
# Processing Record 9 of Set 4 | kenai
# Processing Record 10 of Set 4 | carutapera
# Processing Record 11 of Set 4 | oltu
# Processing Record 12 of Set 4 | dalen
# Processing Record 13 of Set 4 | noyon
# Processing Record 14 of Set 4 | johi
# Processing Record 15 of Set 4 | paamiut
# Processing Record 16 of Set 4 | mogok
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | anadyr
# Processing Record 20 of Set 4 | avera
# City not found. Skipping...
# Processing Record 21 of Set 4 | montmagny
# Processing Record 22 of Set 4 | shitanjing
# Processing Record 23 of Set 4 | osa
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | barranca
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 4 | albanel
# Processing Record 27 of Set 4 | touros
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | vardo
# Processing Record 30 of Set 4 | gravdal
# Processing Record 31 of Set 4 | belmonte
# City not found. Skipping...
# Processing Record 32 of Set 4 | mugumu
# Processing Record 33 of Set 4 | talnakh
# City not found. Skipping...
# Processing Record 34 of Set 4 | whitehorse
# City not found. Skipping...
# Processing Record 35 of Set 4 | dillon
# Processing Record 36 of Set 4 | majalengka
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 4 | ravar
# City not found. Skipping...
# Processing Record 38 of Set 4 | gazojak
# City not found. Skipping...
# Processing Record 39 of Set 4 | asosa
# Processing Record 40 of Set 4 | toropets
# City not found. Skipping...
# Processing Record 41 of Set 4 | carberry
# Processing Record 42 of Set 4 | deming
# Processing Record 43 of Set 4 | dakar
# Processing Record 44 of Set 4 | pedernales
# Processing Record 45 of Set 4 | muhos
# Processing Record 46 of Set 4 | poya
# Processing Record 47 of Set 4 | zyryanka
# City not found. Skipping...
# Processing Record 48 of Set 4 | price
# Processing Record 49 of Set 4 | margate
# Processing Record 50 of Set 4 | faya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 5 | aripuana
# Processing Record 2 of Set 5 | livingston
# Processing Record 3 of Set 5 | ishigaki
# Processing Record 4 of Set 5 | salinopolis
# Processing Record 5 of Set 5 | viedma
# Processing Record 6 of Set 5 | rawson
# Processing Record 7 of Set 5 | huallanca
# Processing Record 8 of Set 5 | wanaka
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 5 | dauphin
# Processing Record 10 of Set 5 | pucallpa
# Processing Record 11 of Set 5 | skibbereen
# City not found. Skipping...
# Processing Record 12 of Set 5 | batagay
# Processing Record 13 of Set 5 | berlevag
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 5 | tchollire
# City not found. Skipping...
# Processing Record 15 of Set 5 | sept-iles
# Processing Record 16 of Set 5 | kaka
# Processing Record 17 of Set 5 | jalapa
# Processing Record 18 of Set 5 | cianorte
# City not found. Skipping...
# Processing Record 19 of Set 5 | baraboo
# Processing Record 20 of Set 5 | miechow
# Processing Record 21 of Set 5 | akureyri
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | poltavka
# Processing Record 24 of Set 5 | kosa
# Processing Record 25 of Set 5 | nayoro
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | georgetown
# Processing Record 28 of Set 5 | tazovskiy
# Processing Record 29 of Set 5 | panguna
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 5 | narsaq
# Processing Record 31 of Set 5 | upernavik
# Processing Record 32 of Set 5 | nshamba
# City not found. Skipping...
# Processing Record 33 of Set 5 | hami
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | luba
# Processing Record 36 of Set 5 | mattru
# Processing Record 37 of Set 5 | dunedin
# City not found. Skipping...
# Processing Record 38 of Set 5 | dosso
# Processing Record 39 of Set 5 | nuuk
# Processing Record 40 of Set 5 | saldanha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | podgornoye
# Processing Record 43 of Set 5 | bubaque
# City not found. Skipping...
# Processing Record 44 of Set 5 | krasnogorsk
# Processing Record 45 of Set 5 | yerbogachen
# Processing Record 46 of Set 5 | launceston
# City not found. Skipping...
# Processing Record 47 of Set 5 | kibala
# Processing Record 48 of Set 5 | kieta
# Processing Record 49 of Set 5 | mackenzie
# Processing Record 50 of Set 5 | leirvik
# Processing Record 1 of Set 6 | kaitangata
# Processing Record 2 of Set 6 | dudinka
# Processing Record 3 of Set 6 | hassleholm
# Processing Record 4 of Set 6 | mbanza-ngungu
# Processing Record 5 of Set 6 | ranong
# City not found. Skipping...
# Processing Record 6 of Set 6 | mossendjo
# Processing Record 7 of Set 6 | alberdi
# Processing Record 8 of Set 6 | jiaocheng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 6 | souillac
# Processing Record 10 of Set 6 | mecca
# City not found. Skipping...
# Processing Record 11 of Set 6 | sumbe
# Processing Record 12 of Set 6 | usvyaty
# Processing Record 13 of Set 6 | opuwo
# City not found. Skipping...
# Processing Record 14 of Set 6 | ixtapa
# Processing Record 15 of Set 6 | pedasi
# Processing Record 16 of Set 6 | sainte-anne-des-monts
# Processing Record 17 of Set 6 | daru
# City not found. Skipping...
# Processing Record 18 of Set 6 | aklavik
# Processing Record 19 of Set 6 | ianca
# Processing Record 20 of Set 6 | marzuq
# City not found. Skipping...
# Processing Record 21 of Set 6 | wanning
# Processing Record 22 of Set 6 | komsomolskiy
# Processing Record 23 of Set 6 | northam
# Processing Record 24 of Set 6 | guiratinga
# Processing Record 25 of Set 6 | cabra
# Processing Record 26 of Set 6 | qaqortoq
# Processing Record 27 of Set 6 | beringovskiy
# Processing Record 28 of Set 6 | sangar
# Processing Record 29 of Set 6 | vihari
# Processing Record 30 of Set 6 | yamada
# Processing Record 31 of Set 6 | ivanava
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 6 | totness
# Processing Record 33 of Set 6 | hailey
# Processing Record 34 of Set 6 | solnechnyy
# Processing Record 35 of Set 6 | palora
# Processing Record 36 of Set 6 | jorpeland
# Processing Record 37 of Set 6 | tartagal
# Processing Record 38 of Set 6 | pasni
# Processing Record 39 of Set 6 | copiapo
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | boende
# Processing Record 42 of Set 6 | xining
# Processing Record 43 of Set 6 | acapulco
# Processing Record 44 of Set 6 | vangaindrano
# Processing Record 45 of Set 6 | kloulklubed
# Processing Record 46 of Set 6 | lithgow
# Processing Record 47 of Set 6 | micheweni
# City not found. Skipping...
# Processing Record 48 of Set 6 | nishihara
# Processing Record 49 of Set 6 | sovetskiy
# Processing Record 50 of Set 6 | shipunovo
# City not found. Skipping...
# Processing Record 1 of Set 7 | suileng
# Processing Record 2 of Set 7 | liyang
# Processing Record 3 of Set 7 | jatai
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | mansa
# Processing Record 6 of Set 7 | vallenar
# City not found. Skipping...
# Processing Record 7 of Set 7 | trinidad
# Processing Record 8 of Set 7 | koszeg
# Processing Record 9 of Set 7 | suici
# Processing Record 10 of Set 7 | brae
# City not found. Skipping...
# Processing Record 11 of Set 7 | olinda
# City not found. Skipping...
# Processing Record 12 of Set 7 | nizwa
# City not found. Skipping...
# Processing Record 13 of Set 7 | jatibonico
# Processing Record 14 of Set 7 | doha
# Processing Record 15 of Set 7 | mweka
# Processing Record 16 of Set 7 | taksimo
# Processing Record 17 of Set 7 | vao
# Processing Record 18 of Set 7 | atakpame
# Processing Record 19 of Set 7 | boyabat
# Processing Record 20 of Set 7 | fenoarivo
# Processing Record 21 of Set 7 | lorengau
# City not found. Skipping...
# Processing Record 22 of Set 7 | xiongzhou
# Processing Record 23 of Set 7 | nanortalik
# City not found. Skipping...
# Processing Record 24 of Set 7 | ridgecrest
# City not found. Skipping...
# Processing Record 25 of Set 7 | katsuura
# Processing Record 26 of Set 7 | douentza
# Processing Record 27 of Set 7 | tevriz
# Processing Record 28 of Set 7 | cabedelo
# Processing Record 29 of Set 7 | kyzyl-oktyabr
# Processing Record 30 of Set 7 | tailai
# Processing Record 31 of Set 7 | deputatskiy
# Processing Record 32 of Set 7 | reconquista
# Processing Record 33 of Set 7 | ostrovnoy
# Processing Record 34 of Set 7 | meulaboh
# Processing Record 35 of Set 7 | kirakira
# City not found. Skipping...
# Processing Record 36 of Set 7 | linden
# Processing Record 37 of Set 7 | srednekolymsk
# Processing Record 38 of Set 7 | arona
# Processing Record 39 of Set 7 | merauke
# Processing Record 40 of Set 7 | nabire
# Processing Record 41 of Set 7 | oranjemund
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 7 | madona
# Processing Record 43 of Set 7 | enderby
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 7 | tera
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 7 | lavrentiya
# Processing Record 46 of Set 7 | tucumcari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 7 | svetlaya
# Processing Record 48 of Set 7 | namatanai
# City not found. Skipping...
# Processing Record 49 of Set 7 | mogadouro
# Processing Record 50 of Set 7 | neepawa
# Processing Record 1 of Set 8 | amapa
# Processing Record 2 of Set 8 | egvekinot
# Processing Record 3 of Set 8 | naryan-mar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 8 | hambantota
# Processing Record 5 of Set 8 | bassila
# Processing Record 6 of Set 8 | karoi
# Processing Record 7 of Set 8 | nouakchott
# Processing Record 8 of Set 8 | atherton
# City not found. Skipping...
# Processing Record 9 of Set 8 | waipawa
# City not found. Skipping...
# Processing Record 10 of Set 8 | curumani
# Processing Record 11 of Set 8 | tautira
# Processing Record 12 of Set 8 | independencia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 8 | humaita
# Processing Record 14 of Set 8 | mantua
# Processing Record 15 of Set 8 | nome
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 8 | sayansk
# Processing Record 17 of Set 8 | sitarganj
# Processing Record 18 of Set 8 | ozernovskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 8 | caravelas
# Processing Record 20 of Set 8 | hofn
# City not found. Skipping...
# Processing Record 21 of Set 8 | chachapoyas
# City not found. Skipping...
# Processing Record 22 of Set 8 | tommot
# City not found. Skipping...
# Processing Record 23 of Set 8 | peleduy
# City not found. Skipping...
# Processing Record 24 of Set 8 | palmer
# Processing Record 25 of Set 8 | sertanopolis
# Processing Record 26 of Set 8 | rumonge
# Processing Record 27 of Set 8 | nizhneudinsk
# City not found. Skipping...
# Processing Record 28 of Set 8 | yebaishou
# Processing Record 29 of Set 8 | beyneu
# Processing Record 30 of Set 8 | kulynychi
# City not found. Skipping...
# Processing Record 31 of Set 8 | lagoa
# Processing Record 32 of Set 8 | nazret
# City not found. Skipping...
# Processing Record 33 of Set 8 | fuyu
# Processing Record 34 of Set 8 | gat
# Processing Record 35 of Set 8 | takestan
# Processing Record 36 of Set 8 | dingli
# City not found. Skipping...
# Processing Record 37 of Set 8 | zhangye
# Processing Record 38 of Set 8 | roald
# Processing Record 39 of Set 8 | ugoofaaru
# Processing Record 40 of Set 8 | maniitsoq
# Processing Record 41 of Set 8 | gizo
# Processing Record 42 of Set 8 | kirensk
# Processing Record 43 of Set 8 | gardiner
# Processing Record 44 of Set 8 | ploemeur
# Processing Record 45 of Set 8 | coquimbo
# Processing Record 46 of Set 8 | khonsa
# Processing Record 47 of Set 8 | ipswich
# Processing Record 48 of Set 8 | muncar
# Processing Record 49 of Set 8 | parabel
# Processing Record 50 of Set 8 | ayagoz
# City not found. Skipping...
# Processing Record 1 of Set 9 | nemuro
# Processing Record 2 of Set 9 | dabeiba
# Processing Record 3 of Set 9 | haradok
# Processing Record 4 of Set 9 | rassvet
# Processing Record 5 of Set 9 | ucluelet
# Processing Record 6 of Set 9 | bozeman
# Processing Record 7 of Set 9 | mazamari
# Processing Record 8 of Set 9 | kiama
# Processing Record 9 of Set 9 | kapit
# Processing Record 10 of Set 9 | aitape
# Processing Record 11 of Set 9 | grindavik
# Processing Record 12 of Set 9 | westport
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 9 | tilichiki
# Processing Record 14 of Set 9 | canmore
# City not found. Skipping...
# Processing Record 15 of Set 9 | zhigansk
# Processing Record 16 of Set 9 | livenka
# Processing Record 17 of Set 9 | uray
# City not found. Skipping...
# Processing Record 18 of Set 9 | inza
# Processing Record 19 of Set 9 | huangmei
# Processing Record 20 of Set 9 | xichang
# Processing Record 21 of Set 9 | padang
# Processing Record 22 of Set 9 | altamont
# Processing Record 23 of Set 9 | guangyuan
# Processing Record 24 of Set 9 | naze
# Processing Record 25 of Set 9 | cap-aux-meules
# Processing Record 26 of Set 9 | khasan
# Processing Record 27 of Set 9 | george
# Processing Record 28 of Set 9 | saryg-sep
# City not found. Skipping...
# Processing Record 29 of Set 9 | kardla
# Processing Record 30 of Set 9 | kutum
# Processing Record 31 of Set 9 | itarema
# Processing Record 32 of Set 9 | benidorm
# City not found. Skipping...
# Processing Record 33 of Set 9 | srandakan
# Processing Record 34 of Set 9 | morehead
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 9 | pinhao
# Processing Record 36 of Set 9 | necochea
# Processing Record 37 of Set 9 | lufilufi
# Processing Record 38 of Set 9 | biedenkopf
# City not found. Skipping...
# Processing Record 39 of Set 9 | dangara
# Processing Record 40 of Set 9 | eureka
# Processing Record 41 of Set 9 | callaway
# Processing Record 42 of Set 9 | buraydah
# Processing Record 43 of Set 9 | ulagan
# City not found. Skipping...
# Processing Record 44 of Set 9 | broome
# Processing Record 45 of Set 9 | hailar
# Processing Record 46 of Set 9 | sorland
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 9 | chihuahua
# Processing Record 48 of Set 9 | muslyumovo
# Processing Record 49 of Set 9 | kolokani
# City not found. Skipping...
# Processing Record 50 of Set 9 | gwadar
# Processing Record 1 of Set 10 | alexandria
# Processing Record 2 of Set 10 | russell
# Processing Record 3 of Set 10 | tornio
# Processing Record 4 of Set 10 | college
# City not found. Skipping...
# Processing Record 5 of Set 10 | washington
# Processing Record 6 of Set 10 | quelimane
# Processing Record 7 of Set 10 | kokopo
# Processing Record 8 of Set 10 | nesbyen
# Processing Record 9 of Set 10 | tripoli
# City not found. Skipping...
# Processing Record 10 of Set 10 | joshimath
# City not found. Skipping...
# Processing Record 11 of Set 10 | batticaloa
# Processing Record 12 of Set 10 | kavaratti
# Processing Record 13 of Set 10 | tigil
# Processing Record 14 of Set 10 | havoysund
# Processing Record 15 of Set 10 | tarauaca
# Processing Record 16 of Set 10 | patiya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 10 | abrau-dyurso
# Processing Record 18 of Set 10 | bira
# Processing Record 19 of Set 10 | novoagansk
# Processing Record 20 of Set 10 | pirassununga
# Processing Record 21 of Set 10 | youkounkoun
# Processing Record 22 of Set 10 | gijon
# Processing Record 23 of Set 10 | jiexiu
# City not found. Skipping...
# Processing Record 24 of Set 10 | bonfim
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Set the dictionary for the DataFrame

raw_data = {
            "City": out_cities,
            "Cloudiness": cloudiness,
            "Country": country,
            "Date": date,
            "Humidity": humidity ,
            "Lat": latitude ,
            "Lng": longitude ,
            "Max Temp": max_temp ,
            "Wind Speed": wind_speed  
            
            }

# %%
# Convert to DataFrame and display the DataFrame
df_weather = pd.DataFrame(raw_data)
df_weather.head()
# Out:
#           City  Cloudiness Country        Date  Humidity     Lat      Lng  \
# 0     hermanus         100      ZA  1578258000        75  -34.42    19.24
# 1         lebu           0      ET  1578258000        71    8.96    38.73
# 2    jamestown          89      AU  1578258000        87  -33.21   138.60
# 3  provideniya         100      RU  1578258000        82   64.42  -173.23
# 4        arman          72      RU  1578258000        67   59.70   150.17
#
#   Max Temp  Wind Speed
# 0    66.09       11.03
# 1    55.35        2.39
# 2    56.25        5.93
# 3   -10.43        9.08
# 4    17.53        7.99

# %%
# Save the output to a csv file "weather_data.csv"
df_weather.to_csv('Output_CSV/weather_data.csv')
#df_weather.to_csv("weather_data.csv")

# %%
# Display the count of all the variables
df_weather.count()
# Out:
# City          474
# Cloudiness    474
# Country       474
# Date          474
# Humidity      474
# Lat           474
# Lng           474
# Max Temp      474
# Wind Speed    474
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date
today_date = date.today().strftime('%m/%d/%Y') 
today_date
# Out:
# '01/05/2020'

# %%
plt.scatter(df_weather["Lat"], df_weather["Max Temp"], edgecolors = "black", facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature ("+ today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max temp (F)")
#plt.xlim(-80,100)
#plt.ylim(min(df_weather["Max Temp"])-20 ,max(df_weather["Max Temp"])+20)
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

#plt.savefig("LatitudeVsTemperaturePlot.png")
plt.savefig("Output_Plots/LatitudeVsTemperaturePlot.pnge.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Humidity"], edgecolors = "black", facecolors="skyblue", s=20)
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title(" City Latitude vs. Humidity (" + today_date + ")" ) 
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsHumidityPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Cloudiness"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsCloudinessPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Wind Speed"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsWindSpeedPlot.png")
plt.show()
